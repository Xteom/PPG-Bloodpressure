# %%
# read json data from file

import json

# read json data from file
with open('mt_data_20230829_1693335696674.json') as f:
    data = json.load(f)

# print data
from pprint import pprint
pprint(data)

# print data keys
print('\n Data keys:')
print(data.keys())
# Out:
# {'datatype': '',
#  'haemodynamicAnalysisSessions': [{'haemodynamicData': {'bpDiastolic': 0,
#                                                         'bpSystolic': 0,
#                                                         'cardiacOutput': 0.0,
#                                                         'heartRate': 0,
#                                                         'sequenceID': 0,
#                                                         'spo2': 0,
#                                                         'strokeVolume': 0.0,
#                                                         'timestamp': '2023-08-29T19:01:28.926605Z'},
#                                    'ppgDataJournalID': '4b15c762-48ca-4d7d-bbee-4f097637d635',
#                                    'sessionTimestamp': '2023-08-29T19:01:28.926605Z'},
#                                   {'haemodynamicData': {'bpDiastolic': 81,
#                                                         'bpSystolic': 120,
# ...

# %%
data.keys()
# Out:
# dict_keys(['datatype', 'userProfile', 'sessionTimestampStart', 'sessionTimestampEnd', 'ppgDataSessions', 'haemodynamicAnalysisSessions'])

# %%
data['ppgDataSessions'][0].keys()
# Out:
# dict_keys(['sessionTimestamp', 'ppgDataJournalFrame'])

# %%
data['ppgDataSessions'][0]['ppgDataJournalFrame']
# Out:
# '{"ir":[87.0,88.0,90.0,92.0,94.0,97.0,100.0,103.0,106.0,109.0,112.0,114.0,117.0,118.0,120.0,121.0,121.0,121.0,120.0,119.0,118.0,117.0,116.0,115.0,113.0,112.0,111.0,110.0,109.0,108.0,107.0,106.0,106.0,106.0,106.0,106.0,107.0,108.0,109.0,110.0,111.0,113.0,114.0,116.0,118.0,120.0,121.0,123.0,125.0,127.0,129.0,130.0,132.0,134.0,135.0,137.0,138.0,139.0,140.0,141.0,142.0,142.0,143.0,143.0,143.0,143.0,143.0,143.0,142.0,142.0,142.0,142.0,142.0,142.0,142.0,141.0,141.0,141.0,140.0,140.0,139.0,138.0,138.0,137.0,137.0,137.0,136.0,136.0,136.0,136.0,136.0,136.0,136.0,136.0,136.0,135.0,135.0,135.0,134.0,133.0,132.0,131.0,129.0,126.0,124.0,121.0,117.0,114.0,110.0,107.0,103.0,100.0,97.0,95.0,93.0,91.0,91.0,90.0,90.0,90.0,91.0,92.0,93.0,95.0,96.0,98.0,100.0,102.0,105.0,107.0,110.0,113.0,117.0,120.0,123.0,126.0,129.0,131.0,133.0,135.0,135.0,136.0,135.0,135.0,133.0,132.0,130.0,129.0,127.0,125.0,123.0,121.0,120.0,119.0,117.0,116.0,116.0,115.0,115.0,114.0,114.0,114.0,115.0,115.0,116.0,117.0,118.0,118.0,11
# ...

# %%
data['haemodynamicAnalysisSessions']
# Out:
# [{'ppgDataJournalID': '4b15c762-48ca-4d7d-bbee-4f097637d635',
#   'sessionTimestamp': '2023-08-29T19:01:28.926605Z',
#   'haemodynamicData': {'sequenceID': 0,
#    'heartRate': 0,
#    'spo2': 0,
#    'bpSystolic': 0,
#    'bpDiastolic': 0,
#    'cardiacOutput': 0.0,
#    'strokeVolume': 0.0,
#    'timestamp': '2023-08-29T19:01:28.926605Z'}},
#  {'ppgDataJournalID': 'b51739db-00ee-4cb3-812c-5381ae285e5c',
#   'sessionTimestamp': '2023-08-29T19:01:23.029919Z',
#   'haemodynamicData': {'sequenceID': 0,
#    'heartRate': 61,
#    'spo2': 97,
#    'bpSystolic': 120,
#    'bpDiastolic': 81,
#    'cardiacOutput': 4.176601,
#    'strokeVolume': 66.80431,
#    'timestamp': '2023-08-29T19:01:23.029919Z'}},
#  {'ppgDataJournalID': 'e8386b01-3f17-4959-8a8f-dfc31947cd46',
#   'sessionTimestamp': '2023-08-29T19:01:11.088041Z',
#   'haemodynamicData': {'sequenceID': 0,
#    'heartRate': 63,
#    'spo2': 96,
#    'bpSystolic': 117,
#    'bpDiastolic': 81,
#    'cardiacOutput': 3.6936855,
# ...
